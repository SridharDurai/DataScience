# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# This notebook serves as a comprehensive exploration and summary of the diverse landscape of data science tools and the ecosystem surrounding them.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Scikit-learn
# 4. TensorFlow
# 5. PyTorch

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python:
#
# 1. Addition: `2 + 3 = 5`
# 2. Subtraction: `5 - 3 = 2`
# 3. Multiplication: `2 * 3 = 6`
# 4. Division: `6 / 2 = 3`
# 5. Exponentiation: `2 ** 3 = 8`
# 6. Modulus: `7 % 3 = 1` (remainder of 7 divided by 3)

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
hours = 200 / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Introduce common libraries used in Data Science
# - Overview of popular Data Science tools
# - Introduction to evaluating arithmetic expressions in Python
# - Converting units of time (e.g., minutes to hours) in Python

# %% [markdown]
# ## Author
#
# Sridhar D
